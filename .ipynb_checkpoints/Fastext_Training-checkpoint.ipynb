# %%
import re
import io
import sys
import spacy
import numpy as np
import pandas as pd

from gensim.parsing.preprocessing import preprocess_string, strip_tags, strip_punctuation, strip_multiple_whitespaces, strip_numeric
from gensim.corpora import WikiCorpus
from gensim.models import FastText

from millenlp.helpers import nlp_utils

import torch
from torch import nn
from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence


from tqdm import tqdm
tqdm.pandas()

pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 2000)

# %% [markdown]
# ## Base FastText Wiki Data

# %%
# %% bash
# wget https://dumps.wikimedia.org/eswiki/latest/eswiki-latest-pages-articles.xml.bz2
# Out:
# UsageError: Cell magic `%%` not found.

# %%
def make_corpus(in_f, out_f):

    """Convert Wikipedia xml dump file to text corpus"""

    output = open(out_f, 'w')
    wiki = WikiCorpus(in_f)

    i = 0
    for text in wiki.get_texts():
        output.write(bytes(' '.join(text), 'utf-8').decode('utf-8') + '\n')
        i = i + 1
        if (i % 10000 == 0):
            print('Processed ' + str(i) + ' articles')
    output.close()
    print('Processing complete!')
    
make_corpus('eswiki-latest-pages-articles.xml.bz2', 'gensim_wiki_corpora')
# Out:
# Processed 10000 articles
# Processed 20000 articles
# Processed 30000 articles
# Processed 40000 articles
# Processed 50000 articles
# Processed 60000 articles
# Processed 70000 articles
# Processed 80000 articles
# Processed 90000 articles
# Processed 100000 articles
# Processed 110000 articles
# Processed 120000 articles
# Processed 130000 articles
# Processed 140000 articles
# Processed 150000 articles
# Processed 160000 articles
# Processed 170000 articles
# Processed 180000 articles
# Processed 190000 articles
# Processed 200000 articles
# Processed 210000 articles
# Processed 220000 articles
# Processed 230000 articles
# Processed 240000 articles
# Processed 250000 articles
# Processed 260000 articles
# Processed 270000 articles
# Processed 280000 articles
# Processed 290000 articles
# Processed 300000 articles
# Processed 310000 articles
# Processed 320000 articles
# Processed 330000 articles
# Processed 340000 articles
# Processed 350000 articles
# Processed 360000 articles
# Processed 370000 articles
# Processed 380000 articles
# Processed 390000 articles
# Processed 400000 articles
# Processed 410000 articles
# Processed 420000 articles
# Processed 430000 articles
# Processed 440000 articles
# Processed 450000 articles
# Processed 460000 articles
# Processed 470000 articles
# Processed 480000 articles
# Processed 490000 articles
# Processed 500000 articles
# Processed 510000 articles
# Processed 520000 articles
# Processed 530000 articles
# Processed 540000 articles
# Processed 550000 articles
# Processed 560000 articles
# Processed 570000 articles
# Processed 580000 articles
# Processed 590000 articles
# Processed 600000 articles
# Processed 610000 articles
# Processed 620000 articles
# Processed 630000 articles
# Processed 640000 articles
# Processed 650000 articles
# Processed 660000 articles
# Processed 670000 articles
# Processed 680000 articles
# Processed 690000 articles
# Processed 700000 articles
# Processed 710000 articles
# Processed 720000 articles
# Processed 730000 articles
# Processed 740000 articles
# Processed 750000 articles
# Processed 760000 articles
# Processed 770000 articles
# Processed 780000 articles
# Processed 790000 articles
# Processed 800000 articles
# Processed 810000 articles
# Processed 820000 articles
# Processed 830000 articles
# Processed 840000 articles
# Processed 850000 articles
# Processed 860000 articles
# Processed 870000 articles
# Processed 880000 articles
# Processed 890000 articles
# Processed 900000 articles
# Processed 910000 articles
# Processed 920000 articles
# Processed 930000 articles
# Processed 940000 articles
# Processed 950000 articles
# Processed 960000 articles
# Processed 970000 articles
# Processed 980000 articles
# Processed 990000 articles
# Processed 1000000 articles
# Processed 1010000 articles
# Processed 1020000 articles
# Processed 1030000 articles
# Processed 1040000 articles
# Processed 1050000 articles
# Processed 1060000 articles
# Processed 1070000 articles
# Processed 1080000 articles
# Processed 1090000 articles
# Processed 1100000 articles
# Processed 1110000 articles
# Processed 1120000 articles
# Processed 1130000 articles
# Processed 1140000 articles
# Processed 1150000 articles
# Processed 1160000 articles
# Processed 1170000 articles
# Processed 1180000 articles
# Processed 1190000 articles
# Processed 1200000 articles
# Processed 1210000 articles
# Processed 1220000 articles
# Processed 1230000 articles
# Processed 1240000 articles
# Processed 1250000 articles
# Processed 1260000 articles
# Processed 1270000 articles
# Processed 1280000 articles
# Processed 1290000 articles
# Processed 1300000 articles
# Processed 1310000 articles
# Processed 1320000 articles
# Processing complete!

# %%
def file_len(fname):
    with open(fname) as f:
        for i, l in enumerate(f):
            pass
    return i + 1
file_len('gensim_wiki_corpora')
# Out:
# 1325626

# %%
def get_batch(n, file, length):
    with open(file) as f:
        batch = []
        for i, l in enumerate(f):
            if l:
                batch += [preprocess_string(l.lower(), [strip_tags, strip_punctuation, strip_multiple_whitespaces, strip_numeric])]
                if (i+1)%n==0 or i == length - 1:
                    yield batch
                    batch = []

# %%
model = FastText(size=300, workers=4)
data_length = file_len('gensim_wiki_corpora')
batch_len = 10000
print("Total number of articules {}".format(data_length))
for i, batch in enumerate(get_batch(batch_len, 'gensim_wiki_corpora', data_length)):
    print("Training batch {} for the {} articles".format(i+1, (i+1)*batch_len))
    if i:
        model.build_vocab(batch, update=True)
    else:
        model.build_vocab(batch)
        
    model.train(batch, total_examples=len(batch), epochs=model.epochs)
# Out:
# Total number of articules 1325626
# Training batch 1 for the 10000 articles
# Training batch 2 for the 20000 articles
# Training batch 3 for the 30000 articles
# Training batch 4 for the 40000 articles
# Training batch 5 for the 50000 articles
# Training batch 6 for the 60000 articles
# Training batch 7 for the 70000 articles
# Training batch 8 for the 80000 articles
# Training batch 9 for the 90000 articles
# Training batch 10 for the 100000 articles
# Training batch 11 for the 110000 articles
# Training batch 12 for the 120000 articles
# Training batch 13 for the 130000 articles
# Training batch 14 for the 140000 articles
# Training batch 15 for the 150000 articles
# Training batch 16 for the 160000 articles
# Training batch 17 for the 170000 articles
# Training batch 18 for the 180000 articles
# Training batch 19 for the 190000 articles
# Training batch 20 for the 200000 articles
# Training batch 21 for the 210000 articles
# Training batch 22 for the 220000 articles
# Training batch 23 for the 230000 articles
# Training batch 24 for the 240000 articles
# Training batch 25 for the 250000 articles
# Training batch 26 for the 260000 articles
# Training batch 27 for the 270000 articles
# Training batch 28 for the 280000 articles
# Training batch 29 for the 290000 articles
# Training batch 30 for the 300000 articles
# Training batch 31 for the 310000 articles
# Training batch 32 for the 320000 articles
# Training batch 33 for the 330000 articles
# Training batch 34 for the 340000 articles
# Training batch 35 for the 350000 articles
# Training batch 36 for the 360000 articles
# Training batch 37 for the 370000 articles
# Training batch 38 for the 380000 articles
# Training batch 39 for the 390000 articles
# Training batch 40 for the 400000 articles
# Training batch 41 for the 410000 articles
# Training batch 42 for the 420000 articles
# Training batch 43 for the 430000 articles
# Training batch 44 for the 440000 articles
# Training batch 45 for the 450000 articles
# Training batch 46 for the 460000 articles
# Training batch 47 for the 470000 articles
# Training batch 48 for the 480000 articles
# Training batch 49 for the 490000 articles
# Training batch 50 for the 500000 articles
# Training batch 51 for the 510000 articles
# Training batch 52 for the 520000 articles
# Training batch 53 for the 530000 articles
# Training batch 54 for the 540000 articles
# Training batch 55 for the 550000 articles
# Training batch 56 for the 560000 articles
# Training batch 57 for the 570000 articles
# Training batch 58 for the 580000 articles
# Training batch 59 for the 590000 articles
# Training batch 60 for the 600000 articles
# Training batch 61 for the 610000 articles
# Training batch 62 for the 620000 articles
# Training batch 63 for the 630000 articles
# Training batch 64 for the 640000 articles
# Training batch 65 for the 650000 articles
# Training batch 66 for the 660000 articles
# Training batch 67 for the 670000 articles
# Training batch 68 for the 680000 articles
# Training batch 69 for the 690000 articles
# Training batch 70 for the 700000 articles
# Training batch 71 for the 710000 articles
# Training batch 72 for the 720000 articles
# Training batch 73 for the 730000 articles
# Training batch 74 for the 740000 articles
# Training batch 75 for the 750000 articles
# Training batch 76 for the 760000 articles
# Training batch 77 for the 770000 articles
# Training batch 78 for the 780000 articles
# Training batch 79 for the 790000 articles
# Training batch 80 for the 800000 articles
# Training batch 81 for the 810000 articles
# Training batch 82 for the 820000 articles
# Training batch 83 for the 830000 articles
# Training batch 84 for the 840000 articles
# Training batch 85 for the 850000 articles
# Training batch 86 for the 860000 articles
# Training batch 87 for the 870000 articles
# Training batch 88 for the 880000 articles
# Training batch 89 for the 890000 articles
# Training batch 90 for the 900000 articles
# Training batch 91 for the 910000 articles
# Training batch 92 for the 920000 articles
# Training batch 93 for the 930000 articles
# Training batch 94 for the 940000 articles
# Training batch 95 for the 950000 articles
# Training batch 96 for the 960000 articles
# Training batch 97 for the 970000 articles
# Training batch 98 for the 980000 articles
# Training batch 99 for the 990000 articles
# Training batch 100 for the 1000000 articles
# Training batch 101 for the 1010000 articles
# Training batch 102 for the 1020000 articles
# Training batch 103 for the 1030000 articles
# Training batch 104 for the 1040000 articles
# Training batch 105 for the 1050000 articles
# Training batch 106 for the 1060000 articles
# Training batch 107 for the 1070000 articles
# Training batch 108 for the 1080000 articles
# Training batch 109 for the 1090000 articles
# Training batch 110 for the 1100000 articles
# Training batch 111 for the 1110000 articles
# Training batch 112 for the 1120000 articles
# Training batch 113 for the 1130000 articles
# Training batch 114 for the 1140000 articles
# Training batch 115 for the 1150000 articles
# Training batch 116 for the 1160000 articles
# Training batch 117 for the 1170000 articles
# Training batch 118 for the 1180000 articles
# Training batch 119 for the 1190000 articles
# Training batch 120 for the 1200000 articles
# Training batch 121 for the 1210000 articles
# Training batch 122 for the 1220000 articles
# Training batch 123 for the 1230000 articles
# Training batch 124 for the 1240000 articles
# Training batch 125 for the 1250000 articles
# Training batch 126 for the 1260000 articles
# Training batch 127 for the 1270000 articles
# Training batch 128 for the 1280000 articles
# Training batch 129 for the 1290000 articles
# Training batch 130 for the 1300000 articles
# Training batch 131 for the 1310000 articles
# Training batch 132 for the 1320000 articles
# Training batch 133 for the 1330000 articles

# %%
model.save("model/basefft")
# Out:
# /home/cristian/anaconda3/envs/nlp/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
len(model.wv.vocab)
# Out:
# 517213

# %% [markdown]
# ## Subred Model Complemented

# %%
model = FastText.load("model/basefft")
# Out:
# /opt/conda/envs/nlp/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
data_length = file_len('subred.txt')
batch_len = 10000
print("Total number of articules {}".format(data_length))
for i, batch in enumerate(get_batch(batch_len, 'subred.txt', data_length)):
    print("Training batch {} for the {} articles".format(i+1, (i+1)*batch_len))
    model.build_vocab(batch, update=True)
    model.train(batch, total_examples=len(batch), epochs=model.epochs)
# Out:
# Total number of articules 50004
# Training batch 1 for the 10000 articles
# Training batch 2 for the 20000 articles
# Training batch 3 for the 30000 articles
# Training batch 4 for the 40000 articles
# Training batch 5 for the 50000 articles
# Training batch 6 for the 60000 articles

# %%
len(model.wv.vocab)
# Out:
# 517389

# %%
model.save("subred_model/subredfft")
# Out:
# /home/cristian/anaconda3/envs/nlp/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %% [markdown]
# ## Model Comparative

# %% [markdown]
# ### Data

# %%
class Embedding(object):
    """Embedding transform"""
    
    def __init__(self, model_loc, D_in):
        """
        Args:
            model_loc (string): Path to the embedding FastText
            D_in (intenger): 
        """
        self.D_in = D_in
        self.embedding_layer = FastText.load(model_loc)  
        self.size = self.embedding_layer.wv.vector_size
        
    def __call__(self, sample):
        tensor = torch.zeros(self.D_in, self.size)
        preprocessed_text = preprocess_string(sample['text'].lower(), [strip_tags, strip_punctuation, strip_multiple_whitespaces, strip_numeric])
        preprocessed_text = [word for word in preprocessed_text if word in self.embedding_layer.wv]
        embedding = torch.tensor(self.embedding_layer.wv[preprocessed_text])
        tensor[:embedding.shape[0], :] = embedding[:embedding.shape[0] if embedding.shape[0] <= self.D_in else self.D_in]
        sample['tensor'] = tensor
        return sample

# %%
class Flatten(object):
    """Flatten transform"""
    
    def __init__(self):
        pass
    
    def __call__(self, sample):
        sample['tensor'] = sample['tensor'].view(-1)
        return sample

# %%
class IterationsDataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, dataset_loc, indices, transform=None):
        """
        Args:
            dataset_loc (string): Path to the xlsx file with texts and annotations.
            indices (list): Indices used to take the iteration and label columns from the DataFrame [Iterations, Labels]
        """
        self.indices = indices
        self.dataset = pd.read_excel(dataset_loc)[indices]
        self.transform = transform
        self.labels =  self.dataset[self.indices[1]].unique().tolist()

    def __len__(self):
        return self.dataset.shape[0]

    def __getitem__(self, idx):
        
        sample = {'text': self.dataset.loc[idx, self.indices[0]], 'label': torch.tensor(self.labels.index(self.dataset.loc[idx, self.indices[1]]))}
        
        if self.transform:
            sample = self.transform(sample)
        
        return sample

# %%
print('MEAN: {:.2f}'.format(dataset.dataset['PREGUNTAS'].apply(lambda x : len(x.split())).mean()))
print('STD: {:.2f}'.format(dataset.dataset['PREGUNTAS'].apply(lambda x : len(x.split())).std()))
# Out:
# MEAN: 11.26
# STD: 9.55

# %% [markdown]
# ### Linear Model

# %%
class FastextTwoLayerNet(nn.Module):
    def __init__(self, D_in, H, D_out, size):
        """
        In the constructor we instantiate two nn.Linear modules and assign them as
        member variables.
        """
        super(FastextTwoLayerNet, self).__init__()
        self.D_in = D_in
        self.size = size
        self.linear1 = torch.nn.Linear(D_in * self.size, H)
        self.linear2 = torch.nn.Linear(H, D_out)
        
    
    def forward(self, input_tensor):
        """
        In the forward function we accept a Tensor of input data and we must return
        a Tensor of output data. We can use Modules defined in the constructor as
        well as arbitrary operators on Tensors.
        """
        h_relu = self.linear1(input_tensor).clamp(min=0)
        y_pred = self.linear2(h_relu)
        return y_pred

# %%
D_in, H, D_out, size = 30, 160, 4, 300

# Dataset object with transforms include
dataset = IterationsDataset('interacciones.xlsx', 
                            ['PREGUNTAS', 'INTENCION CORRECTA'], 
                            transform=transforms.Compose([
                                Embedding("subred_model/subredfft", 30),
                                Flatten()
                            ]))

# Generator to group the batches
dataloader = DataLoader(dataset, batch_size=30,
                        shuffle=True, num_workers=4)

model = FastextTwoLayerNet(D_in, H, D_out, size)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-4)

for i_batch, batch in enumerate(dataloader):
    # Forward pass: Compute predicted y by passing x to the model
    preds = model.forward(batch['tensor'])

    # Compute and print loss
    training_loss = criterion(preds, batch['label'])
    print(i_batch, training_loss.item())

    # Zero gradients, perform a backward pass, and update the weights.
    optimizer.zero_grad()
    training_loss.backward()
    optimizer.step()
# Out:
# /opt/conda/envs/nlp/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# 0 1.394147515296936
# 1 1.40174400806427
# 2 1.3419820070266724
# 3 1.4012501239776611
# 4 1.3670706748962402
# 5 1.3664566278457642
# 6 1.3524558544158936
# 7 1.3217461109161377
# 8 1.3086198568344116
# 9 1.3446156978607178
# 10 1.3024235963821411
# 11 1.3895207643508911
# 12 1.3186475038528442
# 13 1.3512918949127197
# 14 1.4281095266342163
# 15 1.364151120185852
# 16 1.382371187210083
# 17 1.351148009300232
# 18 1.405999779701233
# 19 1.3498706817626953
# 20 1.3687556982040405
# 21 1.3293641805648804
# 22 1.3499890565872192
# 23 1.3910714387893677
# 24 1.3418687582015991
# 25 1.397359848022461
# 26 1.421008586883545
# 27 1.4066191911697388
# 28 1.2973408699035645
# 29 1.3781263828277588
# 30 1.3546721935272217
# 31 1.3246434926986694
# 32 1.3462889194488525
# 33 1.343207836151123
# 34 1.3532249927520752
# 35 1.2992777824401855
# 36 1.3598978519439697
# 37 1.381897211074829
# 38 1.3332953453063965
# 39 1.353472352027893
# 40 1.3514389991760254
# 41 1.3649260997772217
# 42 1.333554744720459
# 43 1.4128493070602417
# 44 1.3817658424377441
# 45 1.3092044591903687
# 46 1.3008836507797241
# 47 1.3077460527420044
# 48 1.3311363458633423
# 49 1.3484565019607544
# 50 1.359028697013855
# 51 1.330744981765747
# 52 1.3811033964157104
# 53 1.3132461309432983
# 54 1.38385808467865
# 55 1.2932522296905518
# 56 1.3510197401046753
# 57 1.3723833560943604
# 58 1.2702406644821167
# 59 1.3114169836044312
# 60 1.347459316253662
# 61 1.3074116706848145
# 62 1.3272074460983276
# 63 1.3332403898239136
# 64 1.3543297052383423
# 65 1.2965564727783203
# 66 1.3035393953323364
# 67 1.3874354362487793
# 68 1.3079994916915894
# 69 1.3205626010894775
# 70 1.3132365942001343
# 71 1.3173366785049438
# 72 1.3338863849639893
# 73 1.2943272590637207
# 74 1.2970141172409058
# 75 1.3336375951766968
# 76 1.2775722742080688
# 77 1.342714786529541
# 78 1.3100029230117798
# 79 1.3077672719955444
# 80 1.3250328302383423
# 81 1.3439017534255981
# 82 1.2886528968811035
# 83 1.3912904262542725
# 84 1.339219331741333
# 85 1.3120580911636353
# 86 1.3348032236099243
# 87 1.3320319652557373
# 88 1.2999356985092163
# 89 1.3320648670196533
# 90 1.3500645160675049
# 91 1.2799293994903564
# 92 1.2914985418319702
# 93 1.3186038732528687
# 94 1.3146045207977295
# 95 1.316475749015808
# 96 1.3087825775146484
# 97 1.339403510093689
# 98 1.319060206413269
# 99 1.3418306112289429
# 100 1.2663028240203857
# 101 1.3081296682357788
# 102 1.291669249534607
# 103 1.317872405052185
# 104 1.2811185121536255
# 105 1.3036656379699707
# 106 1.3443597555160522
# 107 1.3505507707595825
# 108 1.3020402193069458
# 109 1.2824417352676392
# 110 1.2579752206802368

# %%
def predict(text):
    iteration = dataset.transform({'text' : text})
    softmax = nn.Softmax(0)
    pred = softmax(model(iteration['tensor']))
    _, index = torch.max(pred, 0)
    probas = {label : pred[i].item() for i, label in enumerate(dataset.labels)}
    return dataset.labels[index], probas
    
predict('Necesito una cita de medicina general')
# Out:
# ('asignacion',
#  {'asignacion': 0.29861029982566833,
#   'confirmacion': 0.21985498070716858,
#   'cancelacion': 0.217831090092659,
#   'agente': 0.26370370388031006})

# %% [markdown]
# ### GRU MODEL

# %%
class GRULayerNet(nn.Module):
    def __init__(self, H, D_out, size):
        """
        Args:
            H : Number of hidden states
        """   

        super(GRULayerNet, self).__init__()
        self.D_in = D_in
        self.size = size
        self.gru =  nn.GRU(self.size, H, 1, batch_first=True, bidirectional=True)
        
    
    def forward(self, input_tensor):
        """
        In the forward function we accept a Tensor of input data and we must return
        a Tensor of output data. We can use Modules defined in the constructor as
        well as arbitrary operators on Tensors.
        """
        return self.gru(input_tensor)

# %%
D_in, H, D_out, size = 30, 160, 4, 300

# Dataset object with transforms include
dataset = IterationsDataset('interacciones.xlsx', 
                            ['PREGUNTAS', 'INTENCION CORRECTA'], 
                            transform=transforms.Compose([
                                Embedding("subred_model/subredfft", 30)
                            ]))

dataloader = DataLoader(dataset, batch_size=30,
                        shuffle=True, num_workers=4)


# criterion = nn.CrossEntropyLoss()
# optimizer = torch.optim.SGD(model.parameters(), lr=1e-4)

# for i_batch, batch in enumerate(dataloader):

#     # Forward pass: Compute predicted y by passing x to the model
#     preds = model.forward(batch['tensor'])

#     # Compute and print loss
#     training_loss = criterion(preds, batch['label'])
#     print(i_batch, training_loss.item())

#     # Zero gradients, perform a backward pass, and update the weights.
#     optimizer.zero_grad()
#     training_loss.backward()
#     optimizer.step()
# Out:
# /opt/conda/envs/nlp/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
model = GRULayerNet(H, D_out, size)
model(dataset.transform({'text':'Necesito una cita de medicina general'}))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-8cbfe2daef3b> in <module>
#       1 model = GRULayerNet(H, D_out, size)
# ----> 2 model(dataset.transform({'text':'Necesito una cita de medicina general'}))
#
# /opt/conda/envs/nlp/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# <ipython-input-44-cd24ffb58cd5> in forward(self, input_tensor)
#      18         well as arbitrary operators on Tensors.
#      19         """
# ---> 20         return self.gru(input_tensor)
#
# /opt/conda/envs/nlp/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# /opt/conda/envs/nlp/lib/python3.7/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     191         else:
#     192             batch_sizes = None
# --> 193             max_batch_size = input.size(0) if self.batch_first else input.size(1)
#     194             sorted_indices = None
#     195             unsorted_indices = None
#
# AttributeError: 'dict' object has no attribute 'size'

# %%
def predict_dataset(row):
    prediction, probas = predict(row['PREGUNTAS'])
    return [prediction] + [probas[key] for key in probas]

data = dataset.dataset.copy()
data[['prediction', 'asignacion', 'confirmacion', 'cancelacion', 'agente']] = data.progress_apply(lambda x : pd.Series(predict_dataset(x)), axis=1)
data
# Out:
# 100%|██████████| 3324/3324 [00:03<00:00, 974.03it/s]
#                                                                                                                                                                                                                                                                                                PREGUNTAS  \
# 0     querer una cita de medicina general
# 1     necesitar una cita de cirugia de columna
# 2     hago una visita de cirugia plastica
# 3     querer una agenda de gastroenterologia
# 4     quiero una cita de citologia
# 5     podria una cita de hematologia pediatrica
# 6     podria una visita de neurologia adulto
# 7     podria una agenda de nefrologia pediatrica
# 8     podria una agenda de cirugia plastica
# 9     hago una agenda de neurologia adulto
# 10    puede una agenda de ortopedia y traumatologia
# 11    queremos una agenda de citoscopa
# 12    hago una cita de ginecologia general
# 13    podria una agenda de citoscopa
# 14    quiero una consulta de medicina general
# 15    necesitamos una visita con el doctor de medicina general
# 16    puede una cita con el medico de nutricion
# 17    queremos una cita con el especialista de junta de ginecologia
# 18    querer una consulta con el doctor de citologia
# 19    podria una agenda con el medica de reumatologia pediatrica
# 20    querer una visita con el doctor de nutricion
# 21    quiero una cita con el especialista de neurologia
# 22    necesito una cita con el doctora de cirugia general
# 23    necesitamos una visita con el cirujano de citologia
# 24    podria una visita con el cirujano de cardiologia pediatrica
# 25    necesitamos una visita con el cirujana de cardiovascular
# 26    queremos una consulta con el doctora de cirugia bariatrica
# 27    necesito una consulta con el medica de junta de ginecologia
# 28    podria una cita con el medica de neumologia
# 29    querer una visita con el especialista de fisioterapia y rehabilitacion
# 30    necesito una agenda donde el psicologo el 18 agosto
# 31    queremos una cupo donde el otorrinolaringologo el 24 octubre
# 32    querer una cita donde el oftalmologo el veintiseis abril
# 33    necesito una consulta donde el radiologo el 8 diciembre
# 34    necesitar una cupo donde el ortopedista de mano el veinticinco agosto
# 35    necesito una consulta donde el psicologo el cinco abril
# 36    puede una cupo donde el hematologo pediatra el 21 febrero
# 37    podria una agenda donde el nefrologo el 27 diciembre
# 38    hago una cupo donde el cirujano maxilofacial el veintiseis noviembre
# 39    necesitar una agenda donde el reumatologo pediatra el trece septiembre
# 40    necesitamos una agenda donde el generalista el 31 enero
# 41    hago una visita donde el nefrologo el 14 septiembre
# 42    podria una consulta donde el cirugano plastico el 19 febrero
# 43    puede una visita donde el psicologo el veinte enero
# 44    hago una cita donde el oftalmologo el diecisiete enero
# 45    podria dame una consulta con el cirujana de medicina general  esta semana
# 46    podria darme una agenda con el medica de radiografia  esta semana
# 47    podria atender una visita con el medico de cardiologia pediatrica  esta semana
# 48    podria sacar una cita con el cirujana de junta quirurgica de neurocirugia  esta semana
# 99    mi cuñado se desperto muy malo cuando puede atiendame el especialista
# 100   mi hermano se desperto muy malo cuando puede atienda el medica
# 101   mi madre se desperto muy malo cuando puede dar el cirujano
# 102   mi abuelo se desperto muy malo cuando puede dame el doctor
# 103   mi madre se desperto muy malo cuando puede dame el especialista
# 104   mi madre se desperto muy malo cuando puede atender el doctor
# 105   es que dar una cupo para mi padrasto donde el ortopedista pediatrico
# 106   es que tener una visita para mi hijo donde el nefrologo pediatra
# 107   es que dar una cupo para mi padre donde el psiquiatra
# 108   es que atienda una cupo para mi esposo donde el ortopedista pediatrico
# 109   es que vea una visita para mi mujer donde el nefrologo
# 110   es que pideme una cupo para mi abuelo donde el generalista
# 111   es que conseguir una cita para mi yerno donde el nefrologo
# 112   es que dar una cupo para mi padrasto donde el ginecologo oncologico
# 113   es que agendarme una cupo para mi esposa donde el psiquiatra
# 114   es que asignar una agenda para mi nuera donde el anestesiologo
# 115   es que dar una consulta para mi hijo donde el dermatologo
# 116   es que pideme una cupo para mi yerno donde el hematologo
# 117   es que tener una cita para mi mujer donde el cardiologo
# 118   es que conseguir una cita para mi yerno donde el neurologo
# 119   es que atiendame una agenda para mi madrasta donde el cirujano pediatra
# 120   la medica me ordono que se me tomara una medicina general cuando se puede hacerlo
# 121   la medica me ordono que se me tomara una medicina alternativa cuando se puede hacerlo
# 122   la medica me ordono que se me tomara una neumologia pediatrica cuando se puede hacerlo
# 123   la medica me ordono que se me tomara una neurologia adulto cuando se puede hacerlo
# 124   la medica me ordono que se me tomara una citoscopa cuando se puede hacerlo
# 125   la medica me ordono que se me tomara una psiquiatria cuando se puede hacerlo
# 126   la medica me ordono que se me tomara una neurologia cuando se puede hacerlo
# 127   la medica me ordono que se me tomara una gineco-obstetricia cuando se puede hacerlo
# 128   la medica me ordono que se me tomara una ortopedia mano cuando se puede hacerlo
# 129   la medica me ordono que se me tomara una ginecologia general cuando se puede hacerlo
# 130   la medica me ordono que se me tomara una cirugia general cuando se puede hacerlo
# 131   la medica me ordono que se me tomara una ecografia doppler cuando se puede hacerlo
# 132   la medica me ordono que se me tomara una cirugia pediatrica cuando se puede hacerlo
# 133   la medica me ordono que se me tomara una otrorrinolaringologia cuando se puede hacerlo
# 134   la medica me ordono que se me tomara una optometria cuando se puede hacerlo
# 135   cuando el cirujano puede conseguir para ver lo que tengo el brazo
# 136   cuando el medica puede pido para ver lo que tengo el brazo
# 137   cuando el cirujano puede pido para ver lo que tengo el brazo
# 138   cuando el especialista puede asignarme para ver lo que tengo el brazo
# 139   cuando el medico puede asignarme para ver lo que tengo el brazo
# 140   cuando el cirujano puede asignar para ver lo que tengo el brazo
# 141   cuando el medica puede dar para ver lo que tengo el brazo
# 142   cuando el doctora puede atienda para ver lo que tengo el brazo
# 143   cuando el cirujano puede pideme para ver lo que tengo el brazo
# 144   cuando el especialista puede atienda para ver lo que tengo el brazo
# 145   cuando el medico puede dame para ver lo que tengo el brazo
# 146   cuando el doctora puede pedir para ver lo que tengo el brazo
# 147   cuando el medica puede agendeme para ver lo que tengo el brazo
# 3264  0.240441
# 3265  0.240441
# 3266  0.240441
# 3267  0.252689
# 3268  0.252689
# 3269  0.252689
# 3270  0.233640
# 3271  0.233640
# 3272  0.233640
# 3273  0.174360
# 3274  0.174360
# 3275  0.174360
# 3276  0.220151
# 3277  0.220151
# 3278  0.220151
# 3279  0.231251
# 3280  0.231251
# 3281  0.231251
# 3282  0.241860
# 3283  0.241860
# 3284  0.241860
# 3285  0.233566
# 3286  0.216194
# 3287  0.232914
# 3288  0.255475
# 3289  0.254882
# 3290  0.257686
# 3291  0.236992
# 3292  0.236265
# 3293  0.245726
# 3294  0.220975
# 3295  0.223210
# 3296  0.224891
# 3297  0.174198
# 3298  0.174198
# 3299  0.174198
# 3300  0.254440
# 3301  0.254440
# 3302  0.254440
# 3303  0.234761
# 3304  0.204997
# 3305  0.229673
# 3306  0.239852
# 3307  0.237384
# 3308  0.242115
# 3309  0.241242
# 3310  0.271431
# 3311  0.247033
# 3312  0.233672
# 3313  0.231090
# 3314  0.239654
# 3315  0.248994
# 3316  0.247542
# 3317  0.247385
# 3318  0.235046
# 3319  0.235046
# 3320  0.235046
# 3321  0.238088
# 3322  0.238088
# 3323  0.238088
#
# [3324 rows x 7 columns]

# %%
data[data['prediction'] != data['INTENCION CORRECTA']]
# Out:
#                                                                                                                                                                                                                                                                                                    PREGUNTAS  \
# 15    necesitamos una visita con el doctor de medicina general
# 16    puede una cita con el medico de nutricion
# 18    querer una consulta con el doctor de citologia
# 19    podria una agenda con el medica de reumatologia pediatrica
# 20    querer una visita con el doctor de nutricion
# 21    quiero una cita con el especialista de neurologia
# 23    necesitamos una visita con el cirujano de citologia
# 24    podria una visita con el cirujano de cardiologia pediatrica
# 25    necesitamos una visita con el cirujana de cardiovascular
# 26    queremos una consulta con el doctora de cirugia bariatrica
# 27    necesito una consulta con el medica de junta de ginecologia
# 28    podria una cita con el medica de neumologia
# 29    querer una visita con el especialista de fisioterapia y rehabilitacion
# 31    queremos una cupo donde el otorrinolaringologo el 24 octubre
# 33    necesito una consulta donde el radiologo el 8 diciembre
# 34    necesitar una cupo donde el ortopedista de mano el veinticinco agosto
# 36    puede una cupo donde el hematologo pediatra el 21 febrero
# 37    podria una agenda donde el nefrologo el 27 diciembre
# 38    hago una cupo donde el cirujano maxilofacial el veintiseis noviembre
# 40    necesitamos una agenda donde el generalista el 31 enero
# 41    hago una visita donde el nefrologo el 14 septiembre
# 45    podria dame una consulta con el cirujana de medicina general  esta semana
# 46    podria darme una agenda con el medica de radiografia  esta semana
# 47    podria atender una visita con el medico de cardiologia pediatrica  esta semana
# 48    podria sacar una cita con el cirujana de junta quirurgica de neurocirugia  esta semana
# 49    podria agendarme una cita con el especialista de neurologia pediatrica  esta semana
# 50    podria conseguir una visita con el especialista de anestiologia  esta semana
# 51    podria darme una agenda con el medica de neurologia adulto  esta semana
# 52    podria asignarme una agenda con el medico de cirugia plastica  esta semana
# 53    podria atender una visita con el medico de neurologia adulto  esta semana
# 54    podria dame una cita con el cirujana de genetica  esta semana
# 55    podria atender una cupo con el cirujano de radiografia  esta semana
# 56    podria ver una agenda con el doctor de infectologia  esta semana
# 57    podria verme una cita con el especialista de anestiologia  esta semana
# 58    podria asignarme una cita con el medico de ecografia    esta semana
# 59    podria darme una cita con el medica de junta de ginecologia  esta semana
# 65    debo obtener un examen urgente con la cirujana a mas tardar el martes proximo
# 75    para cuando usted puede ver una cita en medicina general
# 76    para cuando usted puede verme una cita en gastroenterologia
# 77    para cuando usted puede verme una cita en cirugia bariatrica
# 78    para cuando usted puede asigneme una cita en nefrologia
# 79    para cuando usted puede pideme una cita en gineco-obstetricia
# 80    para cuando usted puede agendar una cita en ginecologia
# 81    para cuando usted puede pideme una cita en oftalmologia
# 82    para cuando usted puede verme una cita en infectologia pediatrica
# 83    para cuando usted puede ver una cita en ortopedia infantil
# 84    para cuando usted puede dame una cita en cirugia de columna
# 85    para cuando usted puede dame una cita en nefrologia adulto
# 87    para cuando usted puede atiendame una cita en ginecologia general
# 88    para cuando usted puede pedir una cita en taller pedagogico
# 89    para cuando usted puede vea una cita en cirugia general
# 90    mi cuñada se desperto muy malo cuando puede dar el especialista
# 91    mi tia se desperto muy malo cuando puede atienda el doctor
# 92    mi suegro se desperto muy malo cuando puede atienda el medica
# 93    mi suegro se desperto muy malo cuando puede pideme el cirujano
# 94    mi abuela se desperto muy malo cuando puede agendarme el especialista
# 95    mi hermano se desperto muy malo cuando puede ver el cirujana
# 96    mi esposo se desperto muy malo cuando puede atiendame el doctor
# 97    mi suegra se desperto muy malo cuando puede obtener el medica
# 98    mi esposo se desperto muy malo cuando puede ver el cirujano
# 99    mi cuñado se desperto muy malo cuando puede atiendame el especialista
# 100   mi hermano se desperto muy malo cuando puede atienda el medica
# 101   mi madre se desperto muy malo cuando puede dar el cirujano
# 102   mi abuelo se desperto muy malo cuando puede dame el doctor
# 103   mi madre se desperto muy malo cuando puede dame el especialista
# 104   mi madre se desperto muy malo cuando puede atender el doctor
# 112   es que dar una cupo para mi padrasto donde el ginecologo oncologico
# 118   es que conseguir una cita para mi yerno donde el neurologo
# 121   la medica me ordono que se me tomara una medicina alternativa cuando se puede hacerlo
# 123   la medica me ordono que se me tomara una neurologia adulto cuando se puede hacerlo
# 128   la medica me ordono que se me tomara una ortopedia mano cuando se puede hacerlo
# 151   debo dame lo mas pronto posible un especialista de cirugia de columna
# 154   debo atenderme lo mas pronto posible un medico de ginecologia y obstetricia
# 155   debo pedir lo mas pronto posible un cirujana de neumologia pediatrica
# 157   debo agendeme lo mas pronto posible un cirujano de otrorrinolaringologia
# 160   debo atienda lo mas pronto posible un cirujana de cirugia de torax
# 161   debo agendar lo mas pronto posible un medico de ginecologia
# 162   debo pido lo mas pronto posible un especialista de fisiatria
# 163   debo obtener lo mas pronto posible un medica de gastroenterologia
# 164   debo pideme lo mas pronto posible un medico de otologia
# 165   yo soy afiliado con la c.e. numero 8552595325 y estoy llamando porque necesito una agenda urgente con el medico de medicina general cuando podre verme
# 3236  0.240531
# 3237  0.227475
# 3238  0.207936
# 3239  0.184573
# 3243  0.201711
# 3245  0.216061
# 3246  0.220695
# 3247  0.220695
# 3248  0.220695
# 3249  0.224832
# 3250  0.262168
# 3251  0.224159
# 3252  0.236475
# 3253  0.234995
# 3254  0.236864
# 3255  0.161792
# 3256  0.161792
# 3257  0.161792
# 3258  0.240294
# 3259  0.240294
# 3260  0.240294
# 3261  0.250856
# 3262  0.250856
# 3263  0.250856
# 3264  0.240441
# 3265  0.240441
# 3266  0.240441
# 3270  0.233640
# 3271  0.233640
# 3272  0.233640
# 3276  0.220151
# 3277  0.220151
# 3278  0.220151
# 3279  0.231251
# 3280  0.231251
# 3281  0.231251
# 3282  0.241860
# 3283  0.241860
# 3284  0.241860
# 3286  0.216194
# 3291  0.236992
# 3292  0.236265
# 3295  0.223210
# 3296  0.224891
# 3300  0.254440
# 3301  0.254440
# 3302  0.254440
# 3306  0.239852
# 3307  0.237384
# 3310  0.271431
# 3312  0.233672
# 3313  0.231090
# 3314  0.239654
# 3318  0.235046
# 3319  0.235046
# 3320  0.235046
# 3321  0.238088
# 3322  0.238088
# 3323  0.238088
#
# [2170 rows x 7 columns]

# %%
loss = nn.CrossEntropyLoss()
input = torch.randn(3, 5, requires_grad=True)
print(input)
target = torch.empty(3, dtype=torch.long).random_(5)
print(target)
output = loss(input, target)
print(output)
# Out:
# tensor([[ 1.4601e-01,  5.7151e-01, -7.0706e-01, -6.6299e-01,  4.3710e-01],
#         [-2.7718e+00, -5.4043e-04,  6.6015e-01,  1.1862e+00,  3.9423e-01],
#         [-5.3009e-01,  6.1172e-01, -1.4582e-03, -7.4532e-01, -8.5128e-03]],
#        requires_grad=True)
# tensor([2, 2, 2])
# tensor(1.7958, grad_fn=<NllLossBackward>)

# %%
model.wv.vector_size
# Out:
# 300

# %%
weights = torch.FloatTensor(model.wv.vectors)
embedding = nn.Embedding.from_pretrained(weights)
# Get embeddings for index 1
input = torch.LongTensor([1])
embedding(input)
# Out:
# tensor([[-1.1705,  5.0482,  2.4649,  0.7217, -2.4352,  1.1867, -1.1970, -1.9468,
#           1.2807, -1.4742, -0.7545, -0.5262,  4.0642,  0.2096,  0.2314,  0.1138,
#          -1.7481,  0.6004,  1.7987,  1.7062, -2.0083, -0.5639,  1.9007, -1.0101,
#          -1.2910, -1.0263,  1.1214, -2.2167,  4.6265,  1.2347, -0.7115, -0.4033,
#           1.7796, -1.2604,  1.9289, -0.3498, -1.1462,  1.9832, -1.2624, -2.5941,
#           2.8553,  0.3324, -1.6055,  2.5291, -1.4236, -2.4208, -3.3017, -0.8893,
#          -0.0917, -3.5893, -1.1435,  4.4766, -0.5909,  1.2724,  3.2217, -0.5666,
#          -2.2370, -1.5040, -1.5517, -0.3843, -1.6675, -1.1773, -3.9576, -1.1701,
#           0.3911,  0.5919, -0.3836, -1.1477,  0.8444,  2.5014,  2.4875, -2.7076,
#           0.6172,  2.2056, -0.9598, -1.8545, -0.9006, -0.6951,  2.9650,  0.2486,
#           0.7362,  0.1373, -3.1565, -1.1593, -1.7125, -1.0612, -1.4765, -0.2727,
#          -0.7277, -2.9582, -1.2254,  0.6468,  0.7515, -4.0886, -1.1736,  1.3893,
#          -1.1203,  3.4329,  0.1889,  0.5889,  1.0115, -0.2630, -2.4689,  0.7706,
#           1.6401, -0.6203, -5.2448,  2.0195, -2.5889, -0.2345, -2.0620,  2.6647,
#          -0.9116,  3.4643, -2.7310, -1.3936, -1.4434,  2.3925,  3.4389, -1.1153,
#           1.5528,  2.7055, -0.4424,  1.1738,  2.2052, -0.8422, -0.2743, -2.9742,
#          -1.7608, -2.7027, -0.3434, -1.3843,  0.7110, -0.9210, -0.2628,  3.5276,
#          -2.6549, -1.3034,  1.0555, -1.8726,  0.7940, -2.4515,  0.2290,  1.3302,
#           1.9416, -3.5831, -0.1494, -1.2063, -1.4743, -2.4380,  4.1555,  1.7635,
#          -5.3026, -2.4652, -4.3662,  0.1899, -1.7713, -5.1024, -0.5772, -2.6261,
#           0.7597, -2.6951,  2.3716, -1.4474,  0.1146,  0.8428, -0.1511, -0.5631,
#           1.1207, -0.9602,  0.0566,  0.6256,  1.6201, -7.4415,  2.8284, -2.1600,
#          -0.6039, -0.1582, -0.1263,  0.0807, -0.1926,  2.1605, -1.0402, -1.4086,
#          -0.9084, -1.6465,  0.6100, -1.5374,  2.9349,  1.4120, -2.5377,  0.0801,
#          -0.4770,  1.3614,  0.9290,  1.1304, -0.0426, -0.8695, -0.9289, -0.8111,
#          -2.4417,  4.4684, -2.2775,  0.0880,  3.7921, -0.1220, -1.9748,  4.3876,
#          -0.4270,  0.0730,  0.8233,  1.4398, -1.7125,  1.1919,  2.3448,  4.7539,
#           1.0505, -0.5745, -0.5833,  3.4729,  2.1366,  0.7560, -4.3490,  0.1422,
#          -0.7348,  0.1502, -0.1285,  1.2931,  0.4239,  0.9986,  2.1536, -0.7089,
#           1.3111,  0.3055,  1.5532,  1.3432,  0.0940, -2.1768, -1.6936, -0.9931,
#          -2.3804,  0.7168,  1.2767,  0.9907, -0.1918, -0.1176,  0.9224,  0.3298,
#          -0.3571,  0.6067, -3.0772,  0.7649, -0.5945,  1.4584,  2.6348, -1.0550,
#           2.1528,  3.2068,  3.1663, -1.7856,  0.1416, -4.5796,  1.6358, -1.1055,
#          -1.9089, -1.2812, -2.0578, -1.8824,  2.1479, -3.5978,  2.2417, -0.5391,
#          -1.4712,  1.4286,  0.6745,  0.0949, -1.6280,  2.3424,  0.6513, -2.0371,
#           4.5230,  1.1989,  1.5039,  0.5373, -2.9981, -1.3328, -1.8429,  0.1238,
#          -0.8292, -0.8230, -1.5940, -2.8412,  1.0542, -1.1591, -0.7621, -0.1263,
#          -1.0203,  4.9454, -2.0357,  2.3744]])

# %%
weights.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-d48b6a314f07> in <module>
# ----> 1 weights.shape()
#
# TypeError: 'torch.Size' object is not callable

# %%
model.wv.vectors.shape
# Out:
# (517389, 300)

# %%
model.wv.get_vector("hola como estas").shape
# Out:
# (300,)
