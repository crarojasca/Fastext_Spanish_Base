# %%
import re
import io
import spacy
import pandas as pd

from tqdm import tqdm

tqdm.pandas()
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 2000)

# %%
# %% bash
# wget https://dumps.wikimedia.org/eswiki/latest/eswiki-latest-pages-articles.xml.bz2

# %%
import sys
from gensim.corpora import WikiCorpus

def make_corpus(in_f, out_f):

    """Convert Wikipedia xml dump file to text corpus"""

    output = open(out_f, 'w')
    wiki = WikiCorpus(in_f)

    i = 0
    for text in wiki.get_texts():
        output.write(bytes(' '.join(text), 'utf-8').decode('utf-8') + '\n')
        i = i + 1
        if (i % 10000 == 0):
            print('Processed ' + str(i) + ' articles')
    output.close()
    print('Processing complete!')
    
make_corpus('eswiki-latest-pages-articles.xml.bz2', 'gensim_wiki_corpora')
# Out:
# Processed 10000 articles
# Processed 20000 articles
# Processed 30000 articles
# Processed 40000 articles
# Processed 50000 articles
# Processed 60000 articles
# Processed 70000 articles
# Processed 80000 articles
# Processed 90000 articles
# Processed 100000 articles
# Processed 110000 articles
# Processed 120000 articles
# Processed 130000 articles
# Processed 140000 articles
# Processed 150000 articles
# Processed 160000 articles
# Processed 170000 articles
# Processed 180000 articles
# Processed 190000 articles
# Processed 200000 articles
# Processed 210000 articles
# Processed 220000 articles
# Processed 230000 articles
# Processed 240000 articles
# Processed 250000 articles
# Processed 260000 articles
# Processed 270000 articles
# Processed 280000 articles
# Processed 290000 articles
# Processed 300000 articles
# Processed 310000 articles
# Processed 320000 articles
# Processed 330000 articles
# Processed 340000 articles
# Processed 350000 articles
# Processed 360000 articles
# ...

# %%
def file_len(fname):
    with open(fname) as f:
        for i, l in enumerate(f):
            pass
    return i + 1
file_len('gensim_wiki_corpora')
# Out:
# 1325626

# %%
def get_batch(file):
    with open(file) as f:
        for i, l in enumerate(f):
            print(i, end='')
            if i > 50:
                break
        





from gensim.models import FastText

model = FastText(size=300, workers=8)
# Out:
#   File "<ipython-input-17-f5b495e27323>", line 3
#     for i, l in enumerate(f):
#       ^
# IndentationError: expected an indented block

# %%
model.build_vocab(corpus_file='gensim_wiki_corpora')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-13-0869a19ca986> in <module>
# ----> 1 model.build_vocab(corpus_file='gensim_wiki_corpora')
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/gensim/models/fasttext.py in build_vocab(self, sentences, corpus_file, update, progress_per, keep_raw_vocab, trim_rule, **kwargs)
#     702         return super(FastText, self).build_vocab(
#     703             sentences=sentences, corpus_file=corpus_file, update=update, progress_per=progress_per,
# --> 704             keep_raw_vocab=keep_raw_vocab, trim_rule=trim_rule, **kwargs)
#     705
#     706     def _set_train_params(self, **kwargs):
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/gensim/models/base_any2vec.py in build_vocab(self, sentences, corpus_file, update, progress_per, keep_raw_vocab, trim_rule, **kwargs)
# ...

# %%
data = open('gensim_wiki_corpora', 'r')
data.readline()
data.close()

# %%
from gensim.models.wrappers import FastText

pretrained_embedding = FastText.load_fasttext_format('data_embedding/wiki.es/wiki.es.bin')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-a8f0aa7a1be4> in <module>
#       1 from gensim.models.wrappers import FastText
#       2
# ----> 3 pretrained_embedding = FastText.load_fasttext_format('data_embedding/wiki.es/wiki.es.bin')
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/gensim/models/deprecated/fasttext_wrapper.py in load_fasttext_format(cls, model_file, encoding)
#     272             model_file += '.bin'
#     273         model.file_name = model_file
# --> 274         model.load_binary_data(encoding=encoding)
#     275         return model
#     276
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/gensim/models/deprecated/fasttext_wrapper.py in load_binary_data(self, encoding)
#     297
#     298         # TODO use smart_open again when https://github.com/RaRe-Technologies/smart_open/issues/207 will be fixed
# ...

# %%
pretrained_embedding.build_vocab(interactions, update=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-37897553af9c> in <module>
# ----> 1 pretrained_embedding.build_vocab(interactions, update=True)
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/gensim/models/deprecated/word2vec.py in build_vocab(self, sentences, keep_raw_vocab, trim_rule, progress_per, update)
#     710         # trim by min_count & precalculate downsampling
#     711         self.scale_vocab(keep_raw_vocab=keep_raw_vocab, trim_rule=trim_rule, update=update)
# --> 712         self.finalize_vocab(update=update)  # build tables & arrays
#     713
#     714     def build_vocab_from_freq(self, word_freq, keep_raw_vocab=False, corpus_count=None, trim_rule=None, update=False):
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/gensim/models/deprecated/word2vec.py in finalize_vocab(self, update)
#     951             self.reset_weights()
# ...

# %%
import fasttext

model = fasttext.load_model("cc.es.300.bin")

# %%
model["sacar"].shape
# Out:
# (300,)

# %%
print(len(model.words))
# Out:
# 2000000

# %%
file = open("interactions.txt","w") 

for interaction in interactions:
    file.write(interaction + '\n')
    
file.close()

# %%
interactions
# Out:
# ['para una cita para nutricion',
#  'solicitando cita',
#  'para una cita medica',
#  'una cita medica',
#  'nota para pedir una cita en psiquiatria',
#  'una cita de otorrino por favor',
#  'si fuera tan amable para una cita de ortopedia y traumatologia',
#  'cita para medicina general en la uba Primero de Mayo Alvaro joker peleando con peleando con el telefono que iba a estar aqui en el que tuviera pendiente por si acaso no creo que alcance a subir a las 11 me dijo a que hora se sale Sebastian le dije a las 12:20 de pronto hace tiempo para recoger al nino y al ir de ahi si me llamas para ir de ahi para la 72 porque hoy toca ir a la 72 , Pues con Paola tocaria ir los que a las 11',
#  'Si buenos dias fuera tan amable para una cita para con el neurologo',
#  'cita para neumologia para centro diente por favor',
#  'hola necesito una cita de pediatria para mañana a las 5',
#  'alo',
#  'Buenos dias Estoy llamando para pedir una cita para mi sin alternativa',
# ...
